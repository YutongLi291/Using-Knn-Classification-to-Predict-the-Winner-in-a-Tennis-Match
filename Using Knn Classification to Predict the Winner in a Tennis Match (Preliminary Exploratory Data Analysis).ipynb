# %% [markdown]
# Preliminary exploratory data analysis

# %%
library(tidyverse)
library(caret)
# Out:
# Loading required package: lattice
#
# Attaching package: ‘caret’
#
# The following object is masked from ‘package:purrr’:
#
#     lift

# %%
tennis <- read_csv("https://drive.google.com/uc?export=download&id=1fOQ8sy_qMkQiQEAO6uFdRX4tLI8EpSTn")
head(tennis)

# As we can see, the data is readable
# Out:
# Warning message:
# “Missing column names filled in: 'X1' [1]”Parsed with column specification:
# cols(
#   .default = col_double(),
#   tourney_id = col_character(),
#   tourney_name = col_character(),
#   surface = col_character(),
#   tourney_level = col_character(),
#   winner_seed = col_character(),
#   winner_entry = col_character(),
#   winner_name = col_character(),
#   winner_hand = col_character(),
#   winner_ioc = col_character(),
#   loser_seed = col_character(),
#   loser_entry = col_character(),
#   loser_name = col_character(),
#   loser_hand = col_character(),
#   loser_ioc = col_character(),
#   score = col_character(),
#   round = col_character()
# )
# See spec(...) for full column specifications.
#   X1 tourney_id tourney_name surface draw_size tourney_level tourney_date
# 1 0  2019-M020  Brisbane     Hard    32        A             20181231
# 2 1  2019-M020  Brisbane     Hard    32        A             20181231
# ...

# %%
set.seed(1)
set_rows <- tennis %>% 
  unlist() %>% 
  createDataPartition(p = 0.75, list = FALSE)

head(set_rows)

# Gets row numbers for random 0.75 of the data
# Out:
# Warning message in createDataPartition(., p = 0.75, list = FALSE):
# ...

# %%
training_set <- tennis %>% slice(set_rows)
test_set <- tennis %>% slice(-set_rows)
head(training_set)
head(test_set)
# Out:
#   X1 tourney_id tourney_name surface draw_size tourney_level tourney_date
# 1 0  2019-M020  Brisbane     Hard    32        A             20181231
# 2 2  2019-M020  Brisbane     Hard    32        A             20181231
# 3 3  2019-M020  Brisbane     Hard    32        A             20181231
# 4 4  2019-M020  Brisbane     Hard    32        A             20181231
# 5 5  2019-M020  Brisbane     Hard    32        A             20181231
# 6 7  2019-M020  Brisbane     Hard    32        A             20181231
#   match_num winner_id winner_seed ⋯ l_1stIn l_1stWon l_2ndWon l_SvGms l_bpSaved
# 1 300       105453    2           ⋯ 54      34       20       14      10
# 2 298       105453    2           ⋯ 27      15        6        8       1
# 3 297       104542    NA          ⋯ 60      38        9       11       4
# 4 296       106421    4           ⋯ 56      46       19       15       2
# 5 295       104871    NA          ⋯ 54      40       18       15       6
# ...

# %%
# TODO: make table with training set
# Out:
#     X1   tourney_id tourney_name         surface draw_size tourney_level
# 1      0 2019-M020  Brisbane             Hard     32       A
# 2      2 2019-M020  Brisbane             Hard     32       A
# 3     14 2019-M020  Brisbane             Hard     32       A
# 4    210 2019-580   Australian Open      Hard    128       G
# 5    252 2019-580   Australian Open      Hard    128       G
# 6    259 2019-580   Australian Open      Hard    128       G
# 7    404 2019-0407  Rotterdam            Hard     32       A
# 8    416 2019-0407  Rotterdam            Hard     32       A
# 9    567 2019-0495  Dubai                Hard     32       A
# 10   633 2019-M006  Indian Wells Masters Hard    128       M
# 11   657 2019-M006  Indian Wells Masters Hard    128       M
# 12   751 2019-M007  Miami Masters        Hard    128       M
# 13   918 2019-0425  Barcelona            Clay     64       A
# 14   925 2019-0425  Barcelona            Clay     64       A
# ...

# %%
# TODO: Make plot with training set

ggplot(training_)
